# %%
import pandas as pd

# %%
thor_wwii_data_clean=pd.read_csv("WW2_Missions/thor_wwii_data_clean.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14,48,49,51,52,59,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
thor_wwii_aircraft_gloss=pd.read_csv("WW2_Missions/thor_wwii_aircraft_gloss.csv")

# %%
thor_wwii_aircraft_gloss.head(10)
# Out:
#    gloss_id aircraft       name                             full_name  \
# 0         1      A20        A20                    Douglas A-20 Havoc
# 1         2      A24        A24                 Douglass A-24 Banshee
# 2         3      A26        A26                  Douglas A-26 Invader
# 3         4      A36        A36  North American A-36 Apache (Invader)
# 4         5     ALBA   Albacore                       Fairey Albacore
# 5         6     AUDA      Audax                          Hawker Audax
# 6         7      B17       FORT                  B-17 Flying Fortress
# 7         8      B24  Liberator                        B-24 Liberator
# 8         9      B25        B25                         B-25 Mitchell
# 9        10      B26        B26                  Martin B-26 Marauder
#
#                          aircraft_type  \
# 0  Boston Light Bomber / Night-Fighter
# 1         Dive Bomber / Reconnaissance
# 2        Medium Bomber / Heavy Assault
# ...

# %%
aircraft=thor_wwii_aircraft_gloss.rename(columns={'gloss_id':'aircraft_id'})

# %%
thor_wwii_weapon_gloss=pd.read_csv("WW2_Missions/thor_wwii_weapon_gloss.csv")

# %%
thor_wwii_weapon_gloss=thor_wwii_weapon_gloss.rename(columns={'rn':'weapon_id'})

# %%
thor_wwii_weapon_gloss.head()
# Out:
#    weapon_id country                       weapon_name weapon_type  \
# 0          1     USA                  10 lb Incendiary         NaN
# 1          2     USA                 100 lb Incendiary         NaN
# 2          3     USA      100 lb WP (White Phosphrous)         NaN
# 3          4     USA  1000 lb aux fuel tank Incendiary         NaN
# 4          5     USA       136 lb (38x4 Clusters) I-M6        I-M6
#
#   weapon_class  number_of_bomblets   alt_weapon_name  \
# 0           IC                 NaN  AN-M67 or AN-M69
# 1           IC                 NaN             M47A2
# 2           IC                 NaN             M47A2
# 3           IC                 NaN               NaN
# 4           IC                 NaN                M6
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# ...

# %%
Summary_of_Weather=pd.read_csv("Weather/Summary_of_Weather.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Summary_of_Weather.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR ...   FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# ...

# %%
# selecting the col needed from the Summary_of_Weather DF
Weather =pd.DataFrame(Summary_of_Weather,columns = ["STA", "Date","Precip","MaxTemp","MinTemp",
                                                   "MeanTemp", "Snowfall"])
Weather.head()
# Out:
#      STA      Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall
# 0  10001  1942-7-1  1.016  25.555556  22.222222  23.888889        0
# 1  10001  1942-7-2      0  28.888889  21.666667  25.555556        0
# 2  10001  1942-7-3   2.54  26.111111  22.222222  24.444444        0
# 3  10001  1942-7-4   2.54  26.666667  22.222222  24.444444        0
# 4  10001  1942-7-5      0  26.666667  21.666667  24.444444        0

# %%
# read the Weather_Station_Locations CSV file 
Weather_Station_Locations=pd.read_csv("Weather/Weather_Station_Locations.csv")

Weather_Station_Locations.head()
# Out:
#     WBAN            NAME STATE/COUNTRY ID    LAT     LON  ELEV   Latitude  \
# 0  33013          AIN EL               AL  3623N  00637E   611  36.383333
# 1  33031        LA SENIA               AL  3537N  00037E    88  35.616667
# 2  33023  MAISON BLANCHE               AL  3643N  00314E    23  36.716667
# 3  33044        TELERGMA               AL  3607N  00621E   754  36.116667
# 4  12001         TINDOUF               AL  2741N  00809W   443  27.683333
#
#    Longitude
# 0   6.650000
# 1   0.583333
# 2   3.216667
# 3   6.416667
# 4  -8.083333

# %%
# Celening the Weather_Station_Locations DF by droping the unwanted col
weather_station_loc = Weather_Station_Locations.drop(columns=["LAT","LON"])
weather_station_loc.head()
# Out:
#     WBAN            NAME STATE/COUNTRY ID  ELEV   Latitude  Longitude
# 0  33013          AIN EL               AL   611  36.383333   6.650000
# 1  33031        LA SENIA               AL    88  35.616667   0.583333
# 2  33023  MAISON BLANCHE               AL    23  36.716667   3.216667
# 3  33044        TELERGMA               AL   754  36.116667   6.416667
# 4  12001         TINDOUF               AL   443  27.683333  -8.083333

# %%
weather_station_loc['STATE/COUNTRY ID'].unique()
# Out:
# array(['AL', 'AT', 'AU', 'AZ', 'BA', 'BE', 'BN', 'BR', 'BZ', 'CS', 'CT',
#        'CU', 'DR', 'DY', 'EG', 'EQ', 'ER', 'ET', 'FJ', 'FR', 'GH', 'GL',
#        'GR', 'GU', 'GY', 'HA', 'HI', 'IL', 'IN', 'IQ', 'IR', 'IY', 'JM',
#        'JP', 'KO', 'KU', 'LC', 'LI', 'LY', 'MC', 'MT', 'NG', 'NH', 'NI',
#        'NK', 'NU', 'NZ', 'OM', 'PF', 'PH', 'PI', 'PK', 'PM', 'PQ', 'PR',
#        'SG', 'SO', 'SP', 'TD', 'TI', 'TO', 'TS', 'TU', 'UK'], dtype=object)

# %%
thor_wwii_weapon_gloss.head()
# Out:
#    weapon_id country                       weapon_name weapon_type  \
# 0          1     USA                  10 lb Incendiary         NaN
# 1          2     USA                 100 lb Incendiary         NaN
# 2          3     USA      100 lb WP (White Phosphrous)         NaN
# 3          4     USA  1000 lb aux fuel tank Incendiary         NaN
# 4          5     USA       136 lb (38x4 Clusters) I-M6        I-M6
#
#   weapon_class  number_of_bomblets   alt_weapon_name  \
# 0           IC                 NaN  AN-M67 or AN-M69
# 1           IC                 NaN             M47A2
# 2           IC                 NaN             M47A2
# 3           IC                 NaN               NaN
# 4           IC                 NaN                M6
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# ...

# %%
# Droping un-needed col from the wepon gloss DF.
weapons = thor_wwii_weapon_gloss.drop(columns=["weapon_type","weapon_class","number_of_bomblets"])

# %%
#df['1/2 ID'] = df['1/2 ID'].str.upper()
weapons["weapon_name"] = weapons["weapon_name"].str.upper()
weapons.head(10)
# Out:
#    weapon_id country                              weapon_name  \
# 0          1     USA                         10 LB INCENDIARY
# 1          2     USA                        100 LB INCENDIARY
# 2          3     USA             100 LB WP (WHITE PHOSPHROUS)
# 3          4     USA         1000 LB AUX FUEL TANK INCENDIARY
# 4          5     USA              136 LB (38X4 CLUSTERS) I-M6
# 5          6     USA      2000 LB AUX FUEL TANK AS INCENDIARY
# 6          7     USA                     30 LB RAF INCENDIARY
# 7          8     USA          300 LB AUX FUEL TANK INCENDIARY
# 8          9     USA                        300 LB INCENDIARY
# 9         10     USA  360 LB (60X6 CLUSTERS) INCENDIARY I-M13
#
#      alt_weapon_name                                 weapon_description
# 0   AN-M67 or AN-M69  10 lb Incendiary that used White Phosphorous o...
# 1              M47A2  100 lb M47A2 Incendiary usually loaded with ge...
# ...

# %%
weapons.country.value_counts()
# Out:
# USA              50
# Great Britain     7
# New Zealand       2
# Name: country, dtype: int64

# %%
weapons.weapon_name.value_counts()
# Out:
# 4000 LB GP (GP-M56)                             2
# 500 LB INCENDIARY                               2
# 4 LB INCENDIARY                                 2
# 250 LB GP (GP-M57)                              2
# 100 LB INCENDIARY                               1
# 440 LB (110X4 CLUSTERS) I-M17                   1
# 100 LB GP (GP-M30)                              1
# 1000 LB AP (AP-MK 33)                           1
# 69 LB FRAG (3X23 CLUSTERS)                      1
# 500 LB SAP (SA-M58)                             1
# 500 LB GP (GP-M43/M64)                          1
# 20 LB FRAG                                      1
# 300 LB INCENDIARY                               1
# 2000 LB GP (GP-M34/M66)                         1
# 360 LB (60X6 CLUSTERS) INCENDIARY I-M13         1
# 30 LB RAF INCENDIARY                            1
# 512 LB (128X4 CLUSTERS) INCENDIARY I-M7         1
# 10 LB INCENDIARY                                1
# 6 LB INCENDIARY                                 1
# ...

# %%
thor_wwii_data_clean.columns
# Out:
# Index(['wwii_id', 'master_index_number', 'msndate', 'theater', 'naf',
#        'country_flying_mission', 'tgt_country_code', 'tgt_country',
#        'tgt_location', 'tgt_type', 'tgt_id', 'tgt_industry_code',
#        'tgt_industry', 'source_latitude', 'source_longitude', 'latitude',
#        'longitude', 'unit_id', 'mds', 'aircraft_name', 'msn_type',
#        'tgt_priority', 'tgt_priority_explanation', 'ac_attacking', 'altitude',
#        'altitude_feet', 'number_of_he', 'type_of_he', 'lbs_he', 'tons_of_he',
#        'number_of_ic', 'type_of_ic', 'lbs_ic', 'tons_of_ic', 'number_of_frag',
#        'type_of_frag', 'lbs_frag', 'tons_of_frag', 'total_lbs', 'total_tons',
#        'takeoff_base', 'takeoff_country', 'takeoff_latitude',
#        'takeoff_longitude', 'ac_lost', 'ac_damaged', 'ac_airborne',
#        'ac_dropping', 'time_over_target', 'sighting_method_code',
#        'sighting_explanation', 'bda', 'callsign', 'rounds_ammo',
# ...

# %%
mission_columns=['msndate','country_flying_mission','tgt_country','latitude','longitude','aircraft_name','number_of_he','type_of_he','lbs_he','number_of_ic','type_of_ic','lbs_ic','number_of_frag','type_of_frag','lbs_of_frag']

# %%
missions=pd.DataFrame(thor_wwii_data_clean,columns=mission_columns)

# %%
Weather.head()
# Out:
#      STA      Date Precip    MaxTemp    MinTemp   MeanTemp Snowfall
# 0  10001  1942-7-1  1.016  25.555556  22.222222  23.888889        0
# 1  10001  1942-7-2      0  28.888889  21.666667  25.555556        0
# 2  10001  1942-7-3   2.54  26.111111  22.222222  24.444444        0
# 3  10001  1942-7-4   2.54  26.666667  22.222222  24.444444        0
# 4  10001  1942-7-5      0  26.666667  21.666667  24.444444        0

# %%
wd=Weather['Date'].values.tolist()

# %%
new=[]

# %%
for x in wd:
    year,month,day=x.split('-')
    if len(month)<2:
        month='0'+month
    if len(day)<2:
        day='0'+day
    new.append(int(year+month+day))

# %%
del Weather['Date']

# %%
Weather['Date']=new

# %%
weather=Weather.rename(columns={'STA':'station_id'})

# %%
weather['weather_id']=weather.index + 1

# %%
weather.head()
# Out:
#    station_id Precip    MaxTemp    MinTemp   MeanTemp Snowfall      Date  \
# 0       10001  1.016  25.555556  22.222222  23.888889        0  19420701
# 1       10001      0  28.888889  21.666667  25.555556        0  19420702
# 2       10001   2.54  26.111111  22.222222  24.444444        0  19420703
# 3       10001   2.54  26.666667  22.222222  24.444444        0  19420704
# 4       10001      0  26.666667  21.666667  24.444444        0  19420705
#
#    weather_id
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
weather.tail()
# Out:
#         station_id Precip    MaxTemp    MinTemp   MeanTemp Snowfall      Date  \
# 119035       82506      0  28.333333  18.333333  23.333333        0  19451227
# 119036       82506  9.906  29.444444  18.333333  23.888889        0  19451228
# 119037       82506      0  28.333333  18.333333  23.333333        0  19451229
# 119038       82506      0  28.333333  18.333333  23.333333        0  19451230
# 119039       82506      0  29.444444  17.222222  23.333333        0  19451231
#
#         weather_id
# 119035      119036
# 119036      119037
# 119037      119038
# 119038      119039
# 119039      119040

# %%
stations=weather_station_loc.rename(columns={'WBAN':'station_id'})

# %%
stations.head()
# Out:
#    station_id            NAME STATE/COUNTRY ID  ELEV   Latitude  Longitude
# 0       33013          AIN EL               AL   611  36.383333   6.650000
# 1       33031        LA SENIA               AL    88  35.616667   0.583333
# 2       33023  MAISON BLANCHE               AL    23  36.716667   3.216667
# 3       33044        TELERGMA               AL   754  36.116667   6.416667
# 4       12001         TINDOUF               AL   443  27.683333  -8.083333

# %%
missions=missions.rename(columns={'aircraft_name':'aircraft'})

# %%
newdate=[]
md=missions['msndate'].values.tolist()
for d in md:
    year,month,day=d.split('-')
    if len(month)<2:
        month='0'+month
    if len(day)<2:
        day='0'+day
    newdate.append(year+month+day)
del missions['msndate']
missions['Date']=newdate

# %%
missions['mission_id']=missions.index+1

# %%
missions.head()
# Out:
#   country_flying_mission         tgt_country   latitude   longitude aircraft  \
# 0                    USA               ITALY  38.220000   15.370000      A36
# 1                    USA  PHILIPPINE ISLANDS   9.750000  118.750000      A20
# 2                    USA               ITALY  39.270000   16.250000      A36
# 3                    USA               ITALY  38.430000   15.900000      A36
# 4                    USA  PHILIPPINE ISLANDS  16.083333  120.916667      A20
#
#    number_of_he              type_of_he  lbs_he  number_of_ic  \
# 0          40.0  500 LB GP (GP-M43/M64)     NaN           NaN
# 1           NaN      250 LB GP (GP-M57)     NaN           NaN
# 2          36.0  500 LB GP (GP-M43/M64)     NaN           NaN
# 3          30.0  500 LB GP (GP-M43/M64)     NaN           NaN
# 4           NaN      250 LB GP (GP-M57)     NaN           NaN
#
#           type_of_ic  lbs_ic  number_of_frag type_of_frag  lbs_of_frag  \
# ...

# %%
missions['number_of_he']=missions['number_of_he'].fillna(0)

# %%
missions['lbs_he']=missions['lbs_he'].fillna(0)

# %%
missions['number_of_ic']=missions['number_of_ic'].fillna(0)

# %%
missions['lbs_ic']=missions['lbs_ic'].fillna(0)

# %%
missions['number_of_frag']=missions['number_of_frag'].fillna(0)

# %%
missions['lbs_of_frag']=missions['lbs_of_frag'].fillna(0)

# %%
missions['type_of_he']=missions['type_of_he'].fillna('None')

# %%
missions['type_of_ic']=missions['type_of_ic'].fillna('None')

# %%
missions['type_of_frag']=missions['type_of_frag'].fillna('None')

# %%
missions.head()
# Out:
#   country_flying_mission         tgt_country   latitude   longitude aircraft  \
# 0                    USA               ITALY  38.220000   15.370000      A36
# 1                    USA  PHILIPPINE ISLANDS   9.750000  118.750000      A20
# 2                    USA               ITALY  39.270000   16.250000      A36
# 3                    USA               ITALY  38.430000   15.900000      A36
# 4                    USA  PHILIPPINE ISLANDS  16.083333  120.916667      A20
#
#    number_of_he              type_of_he  lbs_he  number_of_ic  \
# 0          40.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 1           0.0      250 LB GP (GP-M57)     0.0           0.0
# 2          36.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 3          30.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 4           0.0      250 LB GP (GP-M57)     0.0           0.0
#
#           type_of_ic  lbs_ic  number_of_frag type_of_frag  lbs_of_frag  \
# ...

# %%
missions=missions.fillna('')

# %%
missions.head()
# Out:
#   country_flying_mission         tgt_country latitude longitude aircraft  \
# 0                    USA               ITALY    38.22     15.37      A36
# 1                    USA  PHILIPPINE ISLANDS     9.75    118.75      A20
# 2                    USA               ITALY    39.27     16.25      A36
# 3                    USA               ITALY    38.43      15.9      A36
# 4                    USA  PHILIPPINE ISLANDS  16.0833   120.917      A20
#
#    number_of_he              type_of_he  lbs_he  number_of_ic  \
# 0          40.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 1           0.0      250 LB GP (GP-M57)     0.0           0.0
# 2          36.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 3          30.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 4           0.0      250 LB GP (GP-M57)     0.0           0.0
#
#           type_of_ic  lbs_ic  number_of_frag type_of_frag  lbs_of_frag  \
# 0               None     0.0             0.0         None          0.0
# ...

# %%
lat=missions['latitude'].tolist()
for l in lat:
    try:
        l=float(l)
    except:
        pass
missions['latitude']=lat

# %%
lon=missions['longitude'].tolist()
for l in lon:
    try:
        l=float(l)
    except:
        pass
missions['longitude']=lon

# %%
missions.isna().sum()
# Out:
# country_flying_mission    0
# tgt_country               0
# latitude                  0
# longitude                 0
# aircraft                  0
# number_of_he              0
# type_of_he                0
# lbs_he                    0
# number_of_ic              0
# type_of_ic                0
# lbs_ic                    0
# number_of_frag            0
# type_of_frag              0
# lbs_of_frag               0
# Date                      0
# mission_id                0
# dtype: int64

# %%
stations.isna().sum()
# Out:
# station_id          0
# NAME                0
# STATE/COUNTRY ID    0
# ELEV                0
# Latitude            0
# Longitude           0
# dtype: int64

# %%
weather['Snowfall']=weather['Snowfall'].fillna(0.0)

# %%
weather.loc[weather['Precip'] == 'T', 'Precip'] = 0

# %%
bad_snow=[]

# %%
snow=weather['Snowfall'].tolist()
for s in snow:
    if s=='#VALUE!':
        s=0.0
    try:
        s=float(s)
    except:
        bad.append(s)
bad_snow
# Out:
# []

# %%
weather['Snowfall']=snow

# %%
weather.isna().sum()
# Out:
# station_id    0
# Precip        0
# MaxTemp       0
# MinTemp       0
# MeanTemp      0
# Snowfall      0
# Date          0
# weather_id    0
# dtype: int64

# %%
weapons=weapons.fillna('')

# %%
weapons.isna().sum()
# Out:
# weapon_id             0
# country               0
# weapon_name           0
# alt_weapon_name       0
# weapon_description    0
# dtype: int64

# %%
aircraft.isna().sum()
# Out:
# aircraft_id      0
# aircraft         0
# name             0
# full_name        0
# aircraft_type    0
# hyperlink        0
# dtype: int64

# %%
missions.head()
# Out:
#   country_flying_mission         tgt_country latitude longitude aircraft  \
# 0                    USA               ITALY    38.22     15.37      A36
# 1                    USA  PHILIPPINE ISLANDS     9.75    118.75      A20
# 2                    USA               ITALY    39.27     16.25      A36
# 3                    USA               ITALY    38.43      15.9      A36
# 4                    USA  PHILIPPINE ISLANDS  16.0833   120.917      A20
#
#    number_of_he              type_of_he  lbs_he  number_of_ic  \
# 0          40.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 1           0.0      250 LB GP (GP-M57)     0.0           0.0
# 2          36.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 3          30.0  500 LB GP (GP-M43/M64)     0.0           0.0
# 4           0.0      250 LB GP (GP-M57)     0.0           0.0
#
#           type_of_ic  lbs_ic  number_of_frag type_of_frag  lbs_of_frag  \
# 0               None     0.0             0.0         None          0.0
# ...

# %%
weather.head()
# Out:
#    station_id Precip    MaxTemp    MinTemp   MeanTemp Snowfall      Date  \
# 0       10001  1.016  25.555556  22.222222  23.888889        0  19420701
# 1       10001      0  28.888889  21.666667  25.555556        0  19420702
# 2       10001   2.54  26.111111  22.222222  24.444444        0  19420703
# 3       10001   2.54  26.666667  22.222222  24.444444        0  19420704
# 4       10001      0  26.666667  21.666667  24.444444        0  19420705
#
#    weather_id
# 0           1
# 1           2
# 2           3
# 3           4
# 4           5

# %%
stations.head()
# Out:
#    station_id            NAME STATE/COUNTRY ID  ELEV   Latitude  Longitude
# 0       33013          AIN EL               AL   611  36.383333   6.650000
# 1       33031        LA SENIA               AL    88  35.616667   0.583333
# 2       33023  MAISON BLANCHE               AL    23  36.716667   3.216667
# 3       33044        TELERGMA               AL   754  36.116667   6.416667
# 4       12001         TINDOUF               AL   443  27.683333  -8.083333

# %%
aircraft.head()
# Out:
#    aircraft_id aircraft      name                             full_name  \
# 0            1      A20       A20                    Douglas A-20 Havoc
# 1            2      A24       A24                 Douglass A-24 Banshee
# 2            3      A26       A26                  Douglas A-26 Invader
# 3            4      A36       A36  North American A-36 Apache (Invader)
# 4            5     ALBA  Albacore                       Fairey Albacore
#
#                          aircraft_type  \
# 0  Boston Light Bomber / Night-Fighter
# 1         Dive Bomber / Reconnaissance
# 2        Medium Bomber / Heavy Assault
# 3          Ground Attack / Dive Bomber
# 4                 Naval Torpedo Bomber
#
#                                            hyperlink
# 0  http://militaryfactory.com/aircraft/detail.asp...
# 1  http://militaryfactory.com/aircraft/detail.asp...
# 2  http://militaryfactory.com/aircraft/detail.asp...
# 3  http://militaryfactory.com/aircraft/detail.asp...
# ...

# %%
weapons.head()
# Out:
#    weapon_id country                       weapon_name   alt_weapon_name  \
# 0          1     USA                  10 LB INCENDIARY  AN-M67 or AN-M69
# 1          2     USA                 100 LB INCENDIARY             M47A2
# 2          3     USA      100 LB WP (WHITE PHOSPHROUS)             M47A2
# 3          4     USA  1000 LB AUX FUEL TANK INCENDIARY
# 4          5     USA       136 LB (38X4 CLUSTERS) I-M6                M6
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# 3  1000 lb Auxiliary fuel tank. When used as ince...
# 4  M6 Cluster containing 38 AN-M50 incendiary bom...

# %%
missions.to_csv('CSV/missions.csv',index=False)

# %%
weather.to_csv('CSV/weather.csv',index=False)

# %%
stations.to_csv('CSV/stations.csv',index=False)

# %%
aircraft.to_csv('CSV/aircraft.csv',index=False)

# %%
weapons.to_csv('CSV/weapons.csv',index=False)
