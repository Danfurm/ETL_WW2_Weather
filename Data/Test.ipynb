# %%
#This script retrieves data from the MySQL server and displays it as a Pandas dataframe so we can check the values are correct

# %%
import csv
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base

# %%
engine = create_engine('mysql://group07:KnuUyh4WWRqHDxNY@cwru-data-project02.ciuevunbeloh.us-east-2.rds.amazonaws.com:3306/group07')
con = engine.connect()
session = Session(bind=engine)

# %%
tables=engine.execute('show tables')

# %%
for t in tables: print(t)
# Out:
# ('aircraft',)
# ('mission',)
# ('station',)
# ('weapon',)
# ('weather',)

# %%
aircraft_test=pd.read_sql('aircraft',con)

# %%
aircraft_test.head()
# Out:
#    aircraft_id aircraft      name                             full_name  \
# 0            1      A20       A20                    Douglas A-20 Havoc
# 1            2      A24       A24                 Douglass A-24 Banshee
# 2            3      A26       A26                  Douglas A-26 Invader
# 3            4      A36       A36  North American A-36 Apache (Invader)
# 4            5     ALBA  Albacore                       Fairey Albacore
#
#                          aircraft_type  \
# 0  Boston Light Bomber / Night-Fighter
# 1         Dive Bomber / Reconnaissance
# 2        Medium Bomber / Heavy Assault
# 3          Ground Attack / Dive Bomber
# 4                 Naval Torpedo Bomber
#
#                                            hyperlink
# 0  http://militaryfactory.com/aircraft/detail.asp...
# 1  http://militaryfactory.com/aircraft/detail.asp...
# 2  http://militaryfactory.com/aircraft/detail.asp...
# 3  http://militaryfactory.com/aircraft/detail.asp...
# ...

# %%
mission_test=pd.read_sql('mission',con)

# %%
mission_test.head()
# Out:
#    mission_id country              target  latitude  longitude aircraft  \
# 0           1     USA               ITALY   38.2200     15.370      A36
# 1           2     USA  PHILIPPINE ISLANDS    9.7500    118.750      A20
# 2           3     USA               ITALY   39.2700     16.250      A36
# 3           4     USA               ITALY   38.4300     15.900      A36
# 4           5     USA  PHILIPPINE ISLANDS   16.0833    120.917      A20
#
#    number_of_he              type_of_he  lbs_of_he  number_of_ic  \
# 0          40.0  500 LB GP (GP-M43/M64)        0.0           0.0
# 1           0.0      250 LB GP (GP-M57)        0.0           0.0
# 2          36.0  500 LB GP (GP-M43/M64)        0.0           0.0
# 3          30.0  500 LB GP (GP-M43/M64)        0.0           0.0
# 4           0.0      250 LB GP (GP-M57)        0.0           0.0
#
#           type_of_ic  lbs_of_ic  number_of_frag type_of_frag  lbs_of_frag  \
# ...

# %%
station_test=pd.read_sql('station',con)

# %%
station_test.head()
# Out:
#    station_id                    name state  elevation  latitude  longitude
# 0       10001                   ACCRA    GH       62.0   5.60000   -0.30000
# 1       10002             CAPE PALMAS    LI     9999.0   4.36667   -7.73333
# 2       10101         FISHERMANS LAKE    LI     9999.0   6.75000  -11.26670
# 3       10102  MARSHALL/ROBERTS FIELD    LI     9999.0   6.23333  -10.43330
# 4       10502              GEORGETOWN    GY       29.0   6.50000  -58.21670

# %%
weapon_test=pd.read_sql('weapon',con)

# %%
weapon_test.head()
# Out:
#    weapon_id country                              name          alt_name  \
# 0          1     USA                  10 LB INCENDIARY  AN-M67 or AN-M69
# 1          2     USA                 100 LB INCENDIARY             M47A2
# 2          3     USA      100 LB WP (WHITE PHOSPHROUS)             M47A2
# 3          4     USA  1000 LB AUX FUEL TANK INCENDIARY
# 4          5     USA       136 LB (38X4 CLUSTERS) I-M6                M6
#
#                                          description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# 3  1000 lb Auxiliary fuel tank. When used as ince...
# 4  M6 Cluster containing 38 AN-M50 incendiary bom...

# %%
weather_test=df=pd.read_sql('weather',con)

# %%
weather_test.head()
# Out:
#    weather_id  station_id  precipitation  max_temp  min_temp  mean_temp  \
# 0           1       10001          1.016   25.5556   22.2222    23.8889
# 1           2       10001          0.000   28.8889   21.6667    25.5556
# 2           3       10001          2.540   26.1111   22.2222    24.4444
# 3           4       10001          2.540   26.6667   22.2222    24.4444
# 4           5       10001          0.000   26.6667   21.6667    24.4444
#
#    snowfall      date
# 0       0.0  19420701
# 1       0.0  19420702
# 2       0.0  19420703
# 3       0.0  19420704
# 4       0.0  19420705
