# %%
import csv
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.orm import Session
from sqlalchemy.ext.declarative import declarative_base

# %%
Base=declarative_base()

# %%
class Station(Base):
    __tablename__='station'
    station_id=Column(Integer, primary_key=True)
    name=Column(String(255))
    state=Column(String(255))
    elevation=Column(Float)
    latitude=Column(Float)
    longitude=Column(Float)

# %%
class Weather(Base):
    __tablename__='weather'
    weather_id=Column(Integer, primary_key=True)
    station_id=Column(Integer)
    precipitation=Column(Float)
    max_temp=Column(Float)
    min_temp=Column(Float)
    mean_temp=Column(Float)
    snowfall=Column(Float)
    date=Column(Integer)

# %%
class Aircraft(Base):
    __tablename__='aircraft'
    aircraft_id=Column(Integer, primary_key=True)
    aircraft=Column(String(255))
    name=Column(String(255))
    full_name=Column(String(255))
    aircraft_type=Column(String(255))
    hyperlink=Column(String(255))

# %%
class Weapon(Base):
    __tablename__='weapon'
    weapon_id=Column(Integer, primary_key=True)
    country=Column(String(255))
    name=Column(String(255))
    alt_name=Column(String(255))
    description=Column(String(255))

# %%
class Mission(Base):
    __tablename__='mission'
    mission_id=Column(Integer, primary_key=True)
    country=Column(String(255))
    target=Column(String(255))
    latitude=Column(Float)
    longitude=Column(Float)
    aircraft=Column(String(255))
    number_of_he=Column(Float)
    type_of_he=Column(String(255))
    lbs_of_he=Column(Float)
    number_of_ic=Column(Float)
    type_of_ic=Column(String(255))
    lbs_of_ic=Column(Float)
    number_of_frag=Column(Float)
    type_of_frag=Column(String(255))
    lbs_of_frag=Column(Float)
    date=Column(String(255))

# %%
engine = create_engine('mysql://group07:KnuUyh4WWRqHDxNY@cwru-data-project02.ciuevunbeloh.us-east-2.rds.amazonaws.com:3306/group07')
con = engine.connect()
session = Session(bind=engine)

# %%
Base.metadata.create_all(engine)

# %%
with open('CSV/stations.csv',newline='') as file:
    reader=csv.reader(file)
    next(reader)
    for row in reader:
        entry=Station(station_id=row[0],name=row[1],state=row[2],elevation=row[3],latitude=row[4],longitude=row[5])
        session.add(entry)
        session.commit()

# %%
with open('CSV/weather.csv',newline='') as file:
    reader=csv.reader(file)
    next(reader)
    entries=0
    for row in reader:
        entry=Weather(station_id=row[0],precipitation=row[1],max_temp=row[2],min_temp=row[3],mean_temp=row[4],snowfall=row[5],date=row[6],weather_id=row[7])
        session.add(entry)
        if entries==100:
            session.commit()
            entries=0
        else:
            entries+=1
    session.commit()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 29")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 30")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 31")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 9")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 12")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 13")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 14")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 15")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 16")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 17")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 18")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 19")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 20")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 21")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 22")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 23")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 24")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 26")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 28")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 35")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 38")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 39")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 40")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 41")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 57")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 72")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 86")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 85")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 62")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 63")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 64")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 78")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 93")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 94")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 97")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 32")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 37")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 67")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 68")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'snowfall' at row 69")
#   result = self._query(query)

# %%
with open('CSV/weapons.csv',newline='') as file:
    reader=csv.reader(file)
    next(reader)
    for row in reader:
        entry=Weapon(weapon_id=row[0],country=row[1],name=row[2],alt_name=row[3],description=row[4])
        session.add(entry)
        session.commit()

# %%
with open('CSV/aircraft.csv',newline='') as file:
    reader=csv.reader(file)
    next(reader)
    for row in reader:
        entry=Aircraft(aircraft_id=row[0],aircraft=row[1],name=row[2],full_name=row[3],aircraft_type=row[4],hyperlink=row[5])
        session.add(entry)
        session.commit()

# %%
with open('CSV/missions.csv',newline='') as file:
    reader=csv.reader(file)
    next(reader)
    entries=0
    for row in reader:
        entry=Mission(country=row[0],target=row[1],latitude=row[2],longitude=row[3],aircraft=row[4],number_of_he=row[5],type_of_he=row[6],lbs_of_he=row[7],number_of_ic=row[8],type_of_ic=row[9],lbs_of_ic=row[10],number_of_frag=row[10],type_of_frag=row[10],lbs_of_frag=row[11],date=row[12],mission_id=row[13])
        session.add(entry)
        if entries==100:
            session.commit()
            entries=0
        else:
            entries+=1
    session.commit()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 86")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 86")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 87")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 87")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 88")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 88")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 89")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 89")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 90")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 90")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 91")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 91")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 92")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 92")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 93")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 93")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 101")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 101")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 1")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 1")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 96")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 96")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 97")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 97")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 11")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 11")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 12")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 12")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 13")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 13")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 52")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 52")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 53")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 53")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 71")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 71")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 72")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 72")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 22")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 22")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 23")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 23")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 24")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 24")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 25")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 25")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 26")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 26")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 27")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 27")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 78")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 78")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 79")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 79")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 80")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 80")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 81")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 81")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 82")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 82")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 4")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 4")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 5")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 5")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 6")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 6")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 7")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 7")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 16")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 16")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 17")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 17")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 56")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 56")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 57")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 57")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 94")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 94")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 95")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 95")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 98")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 98")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 99")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 99")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 100")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 100")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 2")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 2")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 9")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 9")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 10")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 10")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 19")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 19")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 20")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 20")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 21")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 21")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 28")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 28")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 29")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 29")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 30")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 30")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 35")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 35")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 36")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 36")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 37")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 37")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 31")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 31")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 32")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 32")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 38")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 38")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 66")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 66")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 67")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 67")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 3")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 3")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 8")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 8")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 14")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 14")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 15")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 15")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 18")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 18")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 68")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 68")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 69")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 69")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 70")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 70")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 73")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 73")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 74")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 74")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 75")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 75")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 76")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 76")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 77")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 77")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 40")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 40")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 41")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 41")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 42")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 42")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 43")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 43")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 44")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 44")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 45")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 45")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 46")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 46")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 47")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 47")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 48")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 48")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 49")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 49")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 50")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 50")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 51")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 51")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 54")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 54")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 55")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 55")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 85")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 85")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 34")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 34")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 83")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 83")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 84")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 84")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 33")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 33")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 39")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 39")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 65")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 65")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 58")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 58")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 59")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 59")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 62")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 62")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 63")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 63")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 64")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 64")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 61")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 61")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'latitude' at row 60")
#   result = self._query(query)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (1265, "Data truncated for column 'longitude' at row 60")
#   result = self._query(query)
