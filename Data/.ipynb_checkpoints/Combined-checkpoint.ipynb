# %%
import pandas as pd
import datetime as dt
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
thor_wwii_data_clean=pd.read_csv("WW2_Missions/data/thor_wwii_data_clean.csv")
# Out:
# C:\Users\Lena\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (14,48,49,51,52,59,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
thor_wwii_data_clean.columns
# Out:
# Index(['wwii_id', 'master_index_number', 'msndate', 'theater', 'naf',
#        'country_flying_mission', 'tgt_country_code', 'tgt_country',
#        'tgt_location', 'tgt_type', 'tgt_id', 'tgt_industry_code',
#        'tgt_industry', 'source_latitude', 'source_longitude', 'latitude',
#        'longitude', 'unit_id', 'mds', 'aircraft_name', 'msn_type',
#        'tgt_priority', 'tgt_priority_explanation', 'ac_attacking', 'altitude',
#        'altitude_feet', 'number_of_he', 'type_of_he', 'lbs_he', 'tons_of_he',
#        'number_of_ic', 'type_of_ic', 'lbs_ic', 'tons_of_ic', 'number_of_frag',
#        'type_of_frag', 'lbs_frag', 'tons_of_frag', 'total_lbs', 'total_tons',
#        'takeoff_base', 'takeoff_country', 'takeoff_latitude',
#        'takeoff_longitude', 'ac_lost', 'ac_damaged', 'ac_airborne',
#        'ac_dropping', 'time_over_target', 'sighting_method_code',
#        'sighting_explanation', 'bda', 'callsign', 'rounds_ammo',
#        'spares_return_ac', 'wx_fail_ac', 'mech_fail_ac', 'misc_fail_ac',
#        'target_comment', 'mission_comments', 'source',
#        'database_edit_comments'],
#       dtype='object')

# %%
thor_wwii_aircraft_gloss=pd.read_csv("WW2_Missions/data/thor_wwii_aircraft_gloss.csv")

# %%
thor_wwii_aircraft_gloss.head(10)
# Out:
#    gloss_id aircraft       name                             full_name  \
# 0         1      A20        A20                    Douglas A-20 Havoc
# 1         2      A24        A24                 Douglass A-24 Banshee
# 2         3      A26        A26                  Douglas A-26 Invader
# 3         4      A36        A36  North American A-36 Apache (Invader)
# 4         5     ALBA   Albacore                       Fairey Albacore
# 5         6     AUDA      Audax                          Hawker Audax
# 6         7      B17       FORT                  B-17 Flying Fortress
# 7         8      B24  Liberator                        B-24 Liberator
# 8         9      B25        B25                         B-25 Mitchell
# 9        10      B26        B26                  Martin B-26 Marauder
#
#                          aircraft_type  \
# 0  Boston Light Bomber / Night-Fighter
# 1         Dive Bomber / Reconnaissance
# 2        Medium Bomber / Heavy Assault
# 3          Ground Attack / Dive Bomber
# 4                 Naval Torpedo Bomber
# 5                 Biplane Light Bomber
# 6                         Heavy Bomber
# 7                         Heavy Bomber
# 8                        Medium Bomber
# 9                        Medium Bomber
#
#                                            hyperlink
# 0  http://militaryfactory.com/aircraft/detail.asp...
# 1  http://militaryfactory.com/aircraft/detail.asp...
# 2  http://militaryfactory.com/aircraft/detail.asp...
# 3  http://militaryfactory.com/aircraft/detail.asp...
# 4  http://militaryfactory.com/aircraft/detail.asp...
# 5           http://en.wikipedia.org/wiki/Hawker_Hart
# 6  http://boeing.com/history/products/b-17-flying...
# 7  http://militaryfactory.com/aircraft/detail.asp...
# 8  http://militaryfactory.com/aircraft/detail.asp...
# 9  http://militaryfactory.com/aircraft/detail.asp...

# %%
thor_wwii_weapon_gloss=pd.read_csv("WW2_Missions/data/thor_wwii_weapon_gloss.csv")

# %%
thor_wwii_weapon_gloss.head()
# Out:
#    rn country                       weapon_name weapon_type weapon_class  \
# 0   1     USA                  10 lb Incendiary         NaN           IC
# 1   2     USA                 100 lb Incendiary         NaN           IC
# 2   3     USA      100 lb WP (White Phosphrous)         NaN           IC
# 3   4     USA  1000 lb aux fuel tank Incendiary         NaN           IC
# 4   5     USA       136 lb (38x4 Clusters) I-M6        I-M6           IC
#
#    number_of_bomblets   alt_weapon_name  \
# 0                 NaN  AN-M67 or AN-M69
# 1                 NaN             M47A2
# 2                 NaN             M47A2
# 3                 NaN               NaN
# 4                 NaN                M6
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# 3  1000 lb Auxiliary fuel tank. When used as ince...
# 4  M6 Cluster containing 38 AN-M50 incendiary bom...

# %%
Summary_of_Weather=pd.read_csv("Weather/Summary_of_Weather.csv")
# Out:
# C:\Users\Lena\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
Summary_of_Weather.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall PoorWeather  YR ...   FB  FTI ITH  PGT  TSHDSBRSGF  SD3  RHX  RHN  \
# 0        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 1        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 2        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 3        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
# 4        0         NaN  42 ...  NaN  NaN NaN  NaN         NaN  NaN  NaN  NaN
#
#   RVG  WTE
# 0 NaN  NaN
# 1 NaN  NaN
# 2 NaN  NaN
# 3 NaN  NaN
# 4 NaN  NaN
#
# [5 rows x 31 columns]

# %%
# selecting the col needed from the Summary_of_Weather DF
Weather =pd.DataFrame(Summary_of_Weather,columns = ["STA", "Date","Precip","WindGustSpd","MaxTemp","MinTemp",
                                                   "MeanTemp", "Snowfall"])
Weather.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556
# 2  10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
# read the Weather_Station_Locations CSV file 
Weather_Station_Locations=pd.read_csv("Weather/Weather_Station_Locations.csv")

Weather_Station_Locations.head()
# Out:
#     WBAN            NAME STATE/COUNTRY ID    LAT     LON  ELEV   Latitude  \
# 0  33013          AIN EL               AL  3623N  00637E   611  36.383333
# 1  33031        LA SENIA               AL  3537N  00037E    88  35.616667
# 2  33023  MAISON BLANCHE               AL  3643N  00314E    23  36.716667
# 3  33044        TELERGMA               AL  3607N  00621E   754  36.116667
# 4  12001         TINDOUF               AL  2741N  00809W   443  27.683333
#
#    Longitude
# 0   6.650000
# 1   0.583333
# 2   3.216667
# 3   6.416667
# 4  -8.083333

# %%
# Celening the Weather_Station_Locations DF by droping the unwanted col
weather_station_loc = Weather_Station_Locations.drop(columns=["LAT","LON"])
weather_station_loc.head()
# Out:
#     WBAN            NAME STATE/COUNTRY ID  ELEV   Latitude  Longitude
# 0  33013          AIN EL               AL   611  36.383333   6.650000
# 1  33031        LA SENIA               AL    88  35.616667   0.583333
# 2  33023  MAISON BLANCHE               AL    23  36.716667   3.216667
# 3  33044        TELERGMA               AL   754  36.116667   6.416667
# 4  12001         TINDOUF               AL   443  27.683333  -8.083333

# %%
weather_station_loc['STATE/COUNTRY ID'].unique()
# Out:
# array(['AL', 'AT', 'AU', 'AZ', 'BA', 'BE', 'BN', 'BR', 'BZ', 'CS', 'CT',
#        'CU', 'DR', 'DY', 'EG', 'EQ', 'ER', 'ET', 'FJ', 'FR', 'GH', 'GL',
#        'GR', 'GU', 'GY', 'HA', 'HI', 'IL', 'IN', 'IQ', 'IR', 'IY', 'JM',
#        'JP', 'KO', 'KU', 'LC', 'LI', 'LY', 'MC', 'MT', 'NG', 'NH', 'NI',
#        'NK', 'NU', 'NZ', 'OM', 'PF', 'PH', 'PI', 'PK', 'PM', 'PQ', 'PR',
#        'SG', 'SO', 'SP', 'TD', 'TI', 'TO', 'TS', 'TU', 'UK'], dtype=object)

# %%
thor_wwii_weapon_gloss.head()
# Out:
#    rn country                       weapon_name weapon_type weapon_class  \
# 0   1     USA                  10 lb Incendiary         NaN           IC
# 1   2     USA                 100 lb Incendiary         NaN           IC
# 2   3     USA      100 lb WP (White Phosphrous)         NaN           IC
# 3   4     USA  1000 lb aux fuel tank Incendiary         NaN           IC
# 4   5     USA       136 lb (38x4 Clusters) I-M6        I-M6           IC
#
#    number_of_bomblets   alt_weapon_name  \
# 0                 NaN  AN-M67 or AN-M69
# 1                 NaN             M47A2
# 2                 NaN             M47A2
# 3                 NaN               NaN
# 4                 NaN                M6
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# 3  1000 lb Auxiliary fuel tank. When used as ince...
# 4  M6 Cluster containing 38 AN-M50 incendiary bom...

# %%
# Droping un-needed col from the wepon gloss DF.
weapon_gloss = thor_wwii_weapon_gloss.drop(columns=["weapon_type","weapon_class","number_of_bomblets"])
weapon_gloss.head()
# Out:
#    rn country                       weapon_name   alt_weapon_name  \
# 0   1     USA                  10 lb Incendiary  AN-M67 or AN-M69
# 1   2     USA                 100 lb Incendiary             M47A2
# 2   3     USA      100 lb WP (White Phosphrous)             M47A2
# 3   4     USA  1000 lb aux fuel tank Incendiary               NaN
# 4   5     USA       136 lb (38x4 Clusters) I-M6                M6
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# 3  1000 lb Auxiliary fuel tank. When used as ince...
# 4  M6 Cluster containing 38 AN-M50 incendiary bom...

# %%
#df['1/2 ID'] = df['1/2 ID'].str.upper()
weapon_gloss["weapon_name"] = weapon_gloss["weapon_name"].str.upper()
weapon_gloss.head(10)
# Out:
#    rn country                              weapon_name    alt_weapon_name  \
# 0   1     USA                         10 LB INCENDIARY   AN-M67 or AN-M69
# 1   2     USA                        100 LB INCENDIARY              M47A2
# 2   3     USA             100 LB WP (WHITE PHOSPHROUS)              M47A2
# 3   4     USA         1000 LB AUX FUEL TANK INCENDIARY                NaN
# 4   5     USA              136 LB (38X4 CLUSTERS) I-M6                 M6
# 5   6     USA      2000 LB AUX FUEL TANK AS INCENDIARY                NaN
# 6   7     USA                     30 LB RAF INCENDIARY  I.B 30-lb Mk I-IV
# 7   8     USA          300 LB AUX FUEL TANK INCENDIARY                NaN
# 8   9     USA                        300 LB INCENDIARY                M31
# 9  10     USA  360 LB (60X6 CLUSTERS) INCENDIARY I-M13             AN-M13
#
#                                   weapon_description
# 0  10 lb Incendiary that used White Phosphorous o...
# 1  100 lb M47A2 Incendiary usually loaded with ge...
# 2                            100 lb M47A2 Smoke bomb
# 3  1000 lb Auxiliary fuel tank. When used as ince...
# 4  M6 Cluster containing 38 AN-M50 incendiary bom...
# 5  2000 lb Auxiliary fuel tank. When used as ince...
# 6      30 lb Type-J Mk-I Superflamer Incendiary bomb
# 7  300 lb Auxiliary fuel tank. When used as incen...
# 8  300 lb Incendiary cluster bomb usually contain...
# 9  500 lb Cluster containing 60 M-69 incendiary b...

# %%
weapon_gloss.country.value_counts()
# Out:
# USA              50
# Great Britain     7
# New Zealand       2
# Name: country, dtype: int64

# %%
weapon_gloss.weapon_name.value_counts()
# Out:
# 4 LB INCENDIARY                                 2
# 4000 LB GP (GP-M56)                             2
# 500 LB INCENDIARY                               2
# 250 LB GP (GP-M57)                              2
# ATOMIC BOMB (LITTLE BOY)                        1
# 30 LB INCENDIARY                                1
# 100 LB INCENDIARY                               1
# 100 LB GP (GP-M30)                              1
# ATOMIC BOMB (FAT MAN)                           1
# 6 LB INCENDIARY                                 1
# 300 LB GP (GP-31)                               1
# FLARES PYROTECHNICS(PY-M26)                     1
# 500 LB GP (GP-M43/M64)                          1
# DUMMY PARATROOPS                                1
# 650 LB DC                                       1
# 660 LB AUX FUEL TANK AS INCENDIARY              1
# 2000 LB GP (GP-M34/M66)                         1
# 360 LB FRAG (90X4 CLUSTERS)                     1
# 300 LB AUX FUEL TANK INCENDIARY                 1
# 1600 LB AP(AP-MK 1)                             1
# 1000 LB GP (GP-M44/M65)                         1
# 1000 LB AUX FUEL TANK INCENDIARY                1
# 350 LB DC                                       1
# 20 LB FRAG                                      1
# 300 LB INCENDIARY                               1
# 96 LB FRAG (24X4 CLUSTERS)                      1
# 23 LB PARAFRAG                                  1
# 512 LB (128X4 CLUSTERS) INCENDIARY I-M7         1
# 10 LB INCENDIARY                                1
# 10000 LB PUMPKIN BOMB (ATOMIC BOMB TRAINING)    1
# 90 LB FRAG                                      1
# 84 LB INCENDIARY (14X6 CLUSTER) I-M12           1
# 69 LB FRAG (3X23 CLUSTERS)                      1
# 1000 LB SAP(SA-M59)                             1
# 4 LB FRAG                                       1
# 600 LB GP (GP-M32)                              1
# 2000 LB MINES (M-MK 12)                         1
# LEAFLET                                         1
# 23 LB FRAG CLUSTERS (6 X23 PER CLUSTER)         1
# 100 LB WP (WHITE PHOSPHROUS)                    1
# 400 LB FRAG (20X20 CLUSTERS)                    1
# 440 LB (110X4 CLUSTERS) I-M17                   1
# 120 LB FRAG (6X20 CLUSTERS)                     1
# 500 LB SAP (SA-M58)                             1
# 30 LB RAF INCENDIARY                            1
# 1000 LB AP (AP-MK 33)                           1
# 325 LB DC (DB-MK 17/47)                         1
# 136 LB (38X4 CLUSTERS) I-M6                     1
# 360 LB (60X6 CLUSTERS) INCENDIARY I-M13         1
# 260 LB FRAG                                     1
# 1000 LB MINES                                   1
# 23 LB FRAG                                      1
# TORPEDOES MISC                                  1
# 2000 LB AUX FUEL TANK AS INCENDIARY             1
# 500 LB AUX FUEL TANK INCENDIARY                 1
# Name: weapon_name, dtype: int64

# %%
thor=thor_wwii_data_clean.copy()

# %%
thor['database_edit_comments'].value_counts()
# Out:
# 3 DAY VARIABILITY ON DATES / DATA FROM RAF HOME OFFICE REPORTS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   433
# AUSTEN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            62
# DUST CLOUDS                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       26
# NICKEL LEAFLET MISSION                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            23
# NOTIONAL LAT/LONG ADDED TO GEOLOCATE BOMBS TO CORRECT CITY                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        10
# RAF DRAFT NARRATIVE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                4
# "15 BLENHEIMS AND 14 WELLINGTONS WERE DISPATCHED TO BOMB GERMAN WARSHIPS. 5 PLANES FROM EACH FORCE FAILED TO FIND TARGETS IN LOW-CLOUD CONDITIONS. MOST OF THE REMAINING BLENHEIMS CARRIED OUT LOW-LEVEL ATTACKS ON THE POCKET BATTLESHIP ADMIRAL SCHEER AND ON THE CRUISER EMDENIN WILHELMSHAVEN HARBOUR. AT LEAST 3 BOMBS HIT THE ADMIRAL SCHEER BUT THEY FAILED TO EXPLODE; THE EMDENWAS DAMAGED AND SUFFERED SOME CASUALTIES WHEN A BLENHEIM CRASHED ON TO IT. 5 BLENHEIMS WERE SHOT DOWN, ALL OR MOST BY ANTI-AIRCRAFT (FLAK) FIRE; 107 SQUADRON LOST 4 OF ITS 5 PLANES ON THE RAID. THE FIRST BOMBER COMMAND CASUALTIES OF THE WAR ARE BELIEVED TO HAVE BEEN FLIGHT LIEUTENANT W. F. BARTON AND HIS CREW - FLYING OFFICER J. F. ROSS, NAVIGATOR, AND CORPORAL J. L. RICKETTS, WIRELESS OPERATOR/GUNNER - OF 107 SQUADRON, ALL KILLED WHEN BLENHEIM N6184 WAS SHOT DOWN BY ANTI-AIRCRAFT GUNFIRE OF THE ADMIRAL HIPPER."      2
# "LITTLE IS KNOWN OF THE WELLINGTON ATTACKS ON SHIPS AT BRUNSBUTTEL IN THE MOUTH OF THE KIEL CANAL. 4 CREWS REPORTED THAT THEY HAD FOUND TARGETS TO BOMB. OWING TO NAVIGATION ERROR, 2 BOMBS WERE DROPPED ON THE DANISH TOWN OF ESBJERG, 110 MILES NORTH OF BRUNSBUTTEL, AND 2 PEOPLE WERE KILLED THERE. SOME OF THE WELLINGTONS WERE ATTACKED BY GERMAN FIGHTERS AND 2 WELLINGTONS WERE LOST."                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# NICKEL LEAFLET MISSION; RAF DRAFT NARRATIVE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: database_edit_comments, dtype: int64

# %%
del thor['database_edit_comments']

# %%
thor['source'].value_counts()
# Out:
# AFHRA RAF DRAFT NARRATIVE                             37
# DUST CLOUDS IN THE MIDDLE EAST                        25
# "DOOLITTLE AAR; DOOLITTLE RAID 1942, OSPREY PRESS"    19
# IRIS 742.308                                           4
# IRIS # 00129557 CALL 170.3-6 26 AUG 1942               3
# Name: source, dtype: int64

# %%
del thor['source']

# %%
del thor['mission_comments']

# %%
del thor['target_comment']

# %%
del thor['misc_fail_ac']

# %%
del thor['mech_fail_ac']

# %%
del thor['wx_fail_ac']

# %%
del thor['spares_return_ac']

# %%
del thor['callsign']

# %%
del thor['rounds_ammo']

# %%
del thor['bda']

# %%
del thor['sighting_method_code']

# %%
del thor['time_over_target']

# %%
del thor['sighting_explanation']

# %%
del thor['naf']

# %%
del thor['tgt_country_code']

# %%
del thor['ac_dropping']

# %%
del thor['msn_type']

# %%
del thor['tgt_id']

# %%
del thor['tgt_industry_code']

# %%
del thor['tgt_industry']

# %%
missions=thor.copy()
missions.columns
# Out:
# Index(['wwii_id', 'master_index_number', 'msndate', 'theater',
#        'country_flying_mission', 'tgt_country', 'tgt_location', 'tgt_type',
#        'source_latitude', 'source_longitude', 'latitude', 'longitude',
#        'unit_id', 'mds', 'aircraft_name', 'tgt_priority',
#        'tgt_priority_explanation', 'ac_attacking', 'altitude', 'altitude_feet',
#        'number_of_he', 'type_of_he', 'lbs_he', 'tons_of_he', 'number_of_ic',
#        'type_of_ic', 'lbs_ic', 'tons_of_ic', 'number_of_frag', 'type_of_frag',
#        'lbs_frag', 'tons_of_frag', 'total_lbs', 'total_tons', 'takeoff_base',
#        'takeoff_country', 'takeoff_latitude', 'takeoff_longitude', 'ac_lost',
#        'ac_damaged', 'ac_airborne'],
#       dtype='object')

# %%
com = pd.merge(missions, weapon_gloss, left_on = 'type_of_ic', right_on = "weapon_name")

# %%
com['type_of_ic'].value_counts()
# Out:
# 500 LB INCENDIARY                          1742
# 100 LB INCENDIARY                          1129
# 1000 LB AUX FUEL TANK INCENDIARY            863
# 500 LB AUX FUEL TANK INCENDIARY             574
# 4 LB INCENDIARY                             306
# 440 LB (110X4 CLUSTERS) I-M17               251
# 512 LB (128X4 CLUSTERS) INCENDIARY I-M7     205
# 136 LB (38X4 CLUSTERS) I-M6                 177
# 660 LB AUX FUEL TANK AS INCENDIARY           93
# 300 LB AUX FUEL TANK INCENDIARY              90
# 100 LB WP (WHITE PHOSPHROUS)                 72
# 84 LB INCENDIARY (14X6 CLUSTER) I-M12        56
# 360 LB (60X6 CLUSTERS) INCENDIARY I-M13      51
# 10 LB INCENDIARY                             34
# 6 LB INCENDIARY                               3
# 2000 LB AUX FUEL TANK AS INCENDIARY           2
# 30 LB INCENDIARY                              1
# 300 LB INCENDIARY                             1
# 30 LB RAF INCENDIARY                          1
# Name: type_of_ic, dtype: int64

# %%
missions['msndate'] = missions['msndate'].str.replace('-','')

# %%
y = []
for x in missions['msndate']:
    y.append(int(x))
missions['msndate'] = y

# %%
Summary_of_Weather["Date"]= Summary_of_Weather["Date"].str.split("-", n = 2, expand = False)

# %%
missions
# Out:
#         wwii_id  master_index_number   msndate      theater  \
# 0             1                  NaN  19430815          MTO
# 1          4285              20028.0  19450220          PTO
# 2             3                  NaN  19430815          MTO
# 3             4                  NaN  19430815          MTO
# 4          8167              14639.0  19450223          PTO
# 5         11286              20037.0  19450226          PTO
# 6         26429               1343.0  19450311          PTO
# 7         26430              15422.0  19450311          PTO
# 8             9                  NaN  19430815          MTO
# 9            10                  NaN  19430815          MTO
# 10        37836                278.0  19450320          PTO
# 11           12             292817.0  19430815          ETO
# 12           13             292818.0  19430815          ETO
# 13           14              95435.0  19430815          ETO
# 14           15             197541.0  19430815          ETO
# 15           16             197560.0  19430815          ETO
# 16           17              95429.0  19430815          ETO
# 17           18             197535.0  19430815          ETO
# 18           19             197555.0  19430815          ETO
# 19           20              95431.0  19430815          ETO
# 20           21             197537.0  19430815          ETO
# 21           22             197557.0  19430815          ETO
# 22           23              95434.0  19430815          ETO
# 23           24             197540.0  19430815          ETO
# 24           25             197559.0  19430815          ETO
# 25           26              95430.0  19430815          ETO
# 26           27             197536.0  19430815          ETO
# 27           28             197556.0  19430815          ETO
# 28           29             197526.0  19430815          ETO
# 29           30             197528.0  19430815          ETO
# ...         ...                  ...       ...          ...
# 178251   125744                  NaN  19420727          PTO
# 178252   131132                  NaN  19421016          PTO
# 178253    74589                  NaN  19410207          MTO
# 178254   133068                  NaN  19421119          PTO
# 178255   124136                  NaN  19420703          PTO
# 178256   131130                  NaN  19421016          PTO
# 178257   136562                  NaN  19421227          PTO
# 178258   178720              55524.0  19450216          PTO
# 178259   178721              30381.0  19450216          CBI
# 178260   132002              42091.0  19441223          PTO
# 178261   142971              43097.0  19441231          PTO
# 178262   124137                  NaN  19420703          PTO
# 178263   122555                  NaN  19420613          PTO
# 178264   123775                  NaN  19420630          PTO
# 178265   124138                  NaN  19420703          PTO
# 178266   132800                  NaN  19421116          PTO
# 178267   134260                  NaN  19421202          PTO
# 178268   132319                  NaN  19421105          PTO
# 178269   124544                  NaN  19420714          PTO
# 178270    51039                  NaN  19400821  EAST AFRICA
# 178271    54476                  NaN  19400909          MTO
# 178272   123788                  NaN  19420701          PTO
# 178273   124505                  NaN  19420711          PTO
# 178274   124976                  NaN  19420723          PTO
# 178275   134612                  NaN  19421204          PTO
# 178276   135311                  NaN  19421214          PTO
# 178277    55692                  NaN  19400918          MTO
# 178278   133019                  NaN  19421117          PTO
# 178279   178741                  NaN  19450216          PTO
# 178280   122546                  NaN  19420611          PTO
#
#        country_flying_mission                 tgt_country  \
# 0                         USA                       ITALY
# 1                         USA          PHILIPPINE ISLANDS
# 2                         USA                       ITALY
# 3                         USA                       ITALY
# 4                         USA          PHILIPPINE ISLANDS
# 5                         USA          PHILIPPINE ISLANDS
# 6                         USA  FORMOSA AND RYUKYU ISLANDS
# 7                         USA          PHILIPPINE ISLANDS
# 8                         USA                       ITALY
# 9                         USA                       ITALY
# 10                        USA           FRENCH INDO CHINA
# 11              GREAT BRITAIN                     GERMANY
# 12              GREAT BRITAIN                     GERMANY
# 13                        NaN      HOLLAND OR NETHERLANDS
# 14                        NaN      HOLLAND OR NETHERLANDS
# 15                        NaN      HOLLAND OR NETHERLANDS
# 16                        NaN                      FRANCE
# 17                        NaN                      FRANCE
# 18                        NaN                      FRANCE
# 19                        NaN                      FRANCE
# 20                        NaN                      FRANCE
# 21                        NaN                      FRANCE
# 22                        NaN      HOLLAND OR NETHERLANDS
# 23                        NaN      HOLLAND OR NETHERLANDS
# 24                        NaN      HOLLAND OR NETHERLANDS
# 25                        NaN                      FRANCE
# 26                        NaN                      FRANCE
# 27                        NaN                      FRANCE
# 28                        NaN      HOLLAND OR NETHERLANDS
# 29                        NaN      HOLLAND OR NETHERLANDS
# ...                       ...                         ...
# 178251              AUSTRALIA                  NEW GUINEA
# 178252              AUSTRALIA                       TIMOR
# 178253          GREAT BRITAIN                    ETHIOPIA
# 178254              AUSTRALIA         BISMARK ARCHIPELAGO
# 178255              AUSTRALIA                  NEW GUINEA
# 178256              AUSTRALIA                       TIMOR
# 178257                    USA                  NEW GUINEA
# 178258                    USA                       JAPAN
# 178259                    USA                       BURMA
# 178260                    USA             CELEBES ISLANDS
# 178261                    USA             CELEBES ISLANDS
# 178262              AUSTRALIA                  NEW GUINEA
# 178263              AUSTRALIA                       TIMOR
# 178264                    USA                  NEW GUINEA
# 178265              AUSTRALIA                  NEW GUINEA
# 178266              AUSTRALIA                       TIMOR
# 178267              AUSTRALIA                  NEW GUINEA
# 178268              AUSTRALIA                       TIMOR
# 178269              AUSTRALIA                  NEW GUINEA
# 178270           SOUTH AFRICA                     SOMALIA
# 178271           SOUTH AFRICA                    ETHIOPIA
# 178272              AUSTRALIA                       TIMOR
# 178273              AUSTRALIA         BISMARK ARCHIPELAGO
# 178274              AUSTRALIA                  NEW GUINEA
# 178275              AUSTRALIA                  NEW GUINEA
# 178276              AUSTRALIA                  NEW GUINEA
# 178277           SOUTH AFRICA                    ETHIOPIA
# 178278              AUSTRALIA                       TIMOR
# 178279            NEW ZEALAND                 NEW IRELAND
# 178280              AUSTRALIA                         NaN
#
#                                             tgt_location  \
# 0                                              SPADAFORA
# 1                                        PUERTA PRINCESA
# 2                                                COSENZA
# 3                                            GIOJA TAURO
# 4                                            BALETE PASS
# 5                                        PUERTA PRINCESA
# 6                                                FORMOSA
# 7                                                CABALLO
# 8                                                 SCILLA
# 9                                            GIOJA TAURO
# 10                                             HINH DINA
# 11                                                BERLIN
# 12                                                BERLIN
# 13                                              FLUSHING
# 14                                              FLUSHING
# 15                                              FLUSHING
# 16                                                AMIENS
# 17                                                AMIENS
# 18                                                AMIENS
# 19                                                AMIENS
# 20                                                AMIENS
# 21                                                AMIENS
# 22                                              FLUSHING
# 23                                              FLUSHING
# 24                                              FLUSHING
# 25                                                AMIENS
# 26                                                AMIENS
# 27                                                AMIENS
# 28                                              FLUSHING
# 29                                              FLUSHING
# ...                                                  ...
# 178251                                      GONA MISSION
# 178252                                  VILA DE MANATUTO
# 178253                                           DANGILA
# 178254                                       KAVIENG A/D
# 178255                                      SALAMAUA A/D
# 178256                                  VILA DE MANATUTO
# 178257                                      BUNA MISSION
# 178258                                           SHIMIZU
# 178259                                           KALAYWA
# 178260                                         HALMAHERA
# 178261                                        WASILE BAY
# 178262                                      SALAMAUA A/D
# 178263                            5000 T MERCHANT VESSEL
# 178264                                               LAE
# 178265                                      SALAMAUA A/D
# 178266                                          BOBONARO
# 178267                    BUNA AREA; I HIT ON GONA WRECK
# 178268                                          BOBONARO
# 178269                              ALOR/KALABAHI ISLAND
# 178270                                         MOGADISHU
# 178271                            SHASHAMANA (ABYSSINIA)
# 178272                                             AMBON
# 178273                          "PORA PORA, NEW BRITAIN"
# 178274                                      GONA MISSION
# 178275                              SANANANDA POINT AREA
# 178276  BUNA AREA - 5 DESTROYERS / MOUTH OF KUMUSI RIVER
# 178277                                           YAVELLO
# 178278                                            BAUCAU
# 178279                                     KAVIENG SWEEP
# 178280                                               NaN
#
#                            tgt_type source_latitude source_longitude  \
# 0                               NaN      38.2166667          15.3667
# 1               UNIDENTIFIED TARGET             945            11845
# 2                               NaN           3916N             1615
# 3                               NaN           3826N             1554
# 4                       WOODED AREA            1605            12055
# 5               UNIDENTIFIED TARGET             945            11845
# 6               UNIDENTIFIED TARGET            2400            12100
# 7               UNIDENTIFIED TARGET            1420            12035
# 8                               NaN           3814N             1543
# 9                               NaN           3826N             1554
# 10                         SHIPPING            1335            10900
# 11                        CITY AREA            5232             1325
# 12                        CITY AREA            5232             1325
# 13                              NaN            5124              332
# 14                              NaN            5124              332
# 15                              NaN            5124              332
# 16                         AIRDROME            4954              218
# 17                         AIRDROME            4954              218
# 18                         AIRDROME            4954              218
# 19                         AIRDROME            4954              218
# 20                         AIRDROME            4954              218
# 21                         AIRDROME            4954              218
# 22                              NaN            5124              332
# 23                              NaN            5124              332
# 24                              NaN            5124              332
# 25                         AIRDROME            4954              218
# 26                         AIRDROME            4954              218
# 27                         AIRDROME            4954              218
# 28                              NaN            5124              332
# 29                              NaN            5124              332
# ...                             ...             ...              ...
# 178251                         HUTS            -837            14817
# 178252                STATION HOUSE       -8.511389       126.013056
# 178253                          NaN             NaN              NaN
# 178254                     AIRFIELD       -2.579032       150.807331
# 178255                     AIRFIELD        -7.05711       147.044845
# 178256                STATION HOUSE       -8.511389       126.013056
# 178257              ENEMY POSITIONS       -8.674806       148.423919
# 178258                   URBAN AREA            3500            13830
# 178259                      VILLAGE            2038             9257
# 178260          UNIDENTIFIED TARGET             100            12800
# 178261                  SUPPLY AREA             112            12828
# 178262                     AIRFIELD        -7.05711       147.044845
# 178263                     SHIPPING            -828            12515
# 178264                     SHIPPING            -643            14700
# 178265                     AIRFIELD        -7.05711       147.044845
# 178266                    BUILDINGS       -9.031944          125.325
# 178267               ENEMY SHIPPING       -8.617455        148.30538
# 178268                    BUILDINGS       -9.031944          125.325
# 178269  JETTY/ 1 50 TON VESSEL SUNK            -611            15051
# 178270                    AERODROME             NaN              NaN
# 178271                    AERODROME             NaN              NaN
# 178272                         TOWN       -3.695426       128.181405
# 178273                      VILLAGE            -526            15029
# 178274                          NaN            -837            14817
# 178275                          NaN       -8.635757       148.368853
# 178276               ENEMY WARSHIPS       -8.472085       148.234293
# 178277                    AERODROME             NaN              NaN
# 178278                    BUILDINGS       -8.471111       126.458333
# 178279              VARIOUS TARGETS             NaN              NaN
# 178280          ENEMY MERCHANT SHIP            -903            12432
#
#            ...       tons_of_frag  total_lbs total_tons          takeoff_base  \
# 0          ...                NaN        NaN     10.000  PONTE OLIVO AIRFIELD
# 1          ...                NaN        NaN        NaN                   NaN
# 2          ...                NaN        NaN      9.000  PONTE OLIVO AIRFIELD
# 3          ...                NaN        NaN      7.500  PONTE OLIVO AIRFIELD
# 4          ...                NaN        NaN        NaN                   NaN
# 5          ...                NaN        NaN        NaN                   NaN
# 6          ...                NaN        NaN        NaN                   NaN
# 7          ...                NaN        NaN        NaN                   NaN
# 8          ...                NaN        NaN      0.000  PONTE OLIVO AIRFIELD
# 9          ...                NaN        NaN      0.000  PONTE OLIVO AIRFIELD
# 10         ...                NaN        NaN        NaN                   NaN
# 11         ...                NaN        NaN      1.000                   NaN
# 12         ...                NaN        NaN      4.000                   NaN
# 13         ...                NaN        NaN     39.000                   NaN
# 14         ...                NaN        NaN     39.000                   NaN
# 15         ...                NaN        NaN     39.000                   NaN
# 16         ...                NaN        NaN      5.000                   NaN
# 17         ...                NaN        NaN      5.000                   NaN
# 18         ...                NaN        NaN      5.000                   NaN
# 19         ...                NaN        NaN     20.000                   NaN
# 20         ...                NaN        NaN     20.000                   NaN
# 21         ...                NaN        NaN     20.000                   NaN
# 22         ...                NaN        NaN     36.000                   NaN
# 23         ...                NaN        NaN     36.000                   NaN
# 24         ...                NaN        NaN     36.000                   NaN
# 25         ...                NaN        NaN        NaN                   NaN
# 26         ...                NaN        NaN        NaN                   NaN
# 27         ...                NaN        NaN        NaN                   NaN
# 28         ...                NaN        NaN     32.000                   NaN
# 29         ...                NaN        NaN     32.000                   NaN
# ...        ...                ...        ...        ...                   ...
# 178251     ...                1.2     6400.0      3.200                CAIRNS
# 178252     ...                0.0      100.0      0.050                HUGHES
# 178253     ...                NaN     2000.0      1.000              KHARTOUM
# 178254     ...                0.0     4000.0      2.000                CAIRNS
# 178255     ...                0.0     1000.0      0.500          PORT MORESBY
# 178256     ...                0.0     1900.0      0.950                HUGHES
# 178257     ...                0.0     1500.0      0.750                   NaN
# 178258     ...                NaN        NaN      3.000                   NaN
# 178259     ...                NaN        NaN      4.000                   NaN
# 178260     ...                NaN        NaN     25.000                   NaN
# 178261     ...                NaN        NaN     25.000                   NaN
# 178262     ...                0.0     1000.0      0.500          PORT MORESBY
# 178263     ...                0.0     1000.0      0.500                DARWIN
# 178264     ...                0.0     1600.0      0.800                   NaN
# 178265     ...                0.0     1000.0      0.500          PORT MORESBY
# 178266     ...                0.0      900.0      0.450                HUGHES
# 178267     ...                0.0     4000.0      2.000          PORT MORESBY
# 178268     ...                0.0      400.0      0.200                HUGHES
# 178269     ...                0.0     3000.0      1.500                DARWIN
# 178270     ...                NaN        NaN      0.000               NAIROBI
# 178271     ...                NaN    12000.0      6.000               NAIROBI
# 178272     ...                0.0     2250.0      1.125                DARWIN
# 178273     ...                0.0     3000.0      1.500          PORT MORESBY
# 178274     ...                0.0     1000.0      0.500          PORT MORESBY
# 178275     ...                0.0     2500.0      1.250                   NaN
# 178276     ...                0.0     4500.0      2.250                   NaN
# 178277     ...                NaN        0.0      0.000               NAIROBI
# 178278     ...                0.0     4800.0      2.400       BATCHELOR FIELD
# 178279     ...                NaN     8000.0      4.000                   NaN
# 178280     ...                0.0     1000.0      0.500                DARWIN
#
#        takeoff_country takeoff_latitude takeoff_longitude  ac_lost  \
# 0               SICILY        37.131022         14.321464      NaN
# 1                  NaN              NaN               NaN      NaN
# 2               SICILY        37.131022         14.321464      NaN
# 3               SICILY        37.131022         14.321464      NaN
# 4                  NaN              NaN               NaN      NaN
# 5                  NaN              NaN               NaN      NaN
# 6                  NaN              NaN               NaN      NaN
# 7                  NaN              NaN               NaN      NaN
# 8               SICILY        37.131022         14.321464      NaN
# 9               SICILY        37.131022         14.321464      NaN
# 10                 NaN              NaN               NaN      NaN
# 11                 NaN              NaN               NaN      NaN
# 12                 NaN              NaN               NaN      NaN
# 13                 NaN              NaN               NaN      NaN
# 14                 NaN              NaN               NaN      NaN
# 15                 NaN              NaN               NaN      NaN
# 16                 NaN              NaN               NaN      NaN
# 17                 NaN              NaN               NaN      NaN
# 18                 NaN              NaN               NaN      NaN
# 19                 NaN              NaN               NaN      NaN
# 20                 NaN              NaN               NaN      NaN
# 21                 NaN              NaN               NaN      NaN
# 22                 NaN              NaN               NaN      NaN
# 23                 NaN              NaN               NaN      NaN
# 24                 NaN              NaN               NaN      NaN
# 25                 NaN              NaN               NaN      NaN
# 26                 NaN              NaN               NaN      NaN
# 27                 NaN              NaN               NaN      NaN
# 28                 NaN              NaN               NaN      NaN
# 29                 NaN              NaN               NaN      NaN
# ...                ...              ...               ...      ...
# 178251       AUSTRALIA              NaN               NaN      NaN
# 178252       AUSTRALIA              NaN               NaN      NaN
# 178253           SUDAN        15.580000         32.520000      NaN
# 178254       AUSTRALIA              NaN               NaN      NaN
# 178255      NEW GUINEA              NaN               NaN      NaN
# 178256       AUSTRALIA              NaN               NaN      NaN
# 178257             NaN              NaN               NaN      NaN
# 178258             NaN              NaN               NaN      NaN
# 178259             NaN              NaN               NaN      NaN
# 178260             NaN              NaN               NaN      NaN
# 178261             NaN              NaN               NaN      NaN
# 178262      NEW GUINEA              NaN               NaN      NaN
# 178263       AUSTRALIA              NaN               NaN      NaN
# 178264             NaN              NaN               NaN      NaN
# 178265      NEW GUINEA              NaN               NaN      NaN
# 178266       AUSTRALIA              NaN               NaN      NaN
# 178267      NEW GUINEA              NaN               NaN      NaN
# 178268       AUSTRALIA              NaN               NaN      NaN
# 178269       AUSTRALIA              NaN               NaN      NaN
# 178270           KENYA        -1.283300         36.816700      NaN
# 178271           KENYA        -1.283300         36.816700      1.0
# 178272       AUSTRALIA              NaN               NaN      NaN
# 178273      NEW GUINEA              NaN               NaN      NaN
# 178274      NEW GUINEA              NaN               NaN      NaN
# 178275             NaN              NaN               NaN      NaN
# 178276             NaN              NaN               NaN      NaN
# 178277           KENYA        -1.283300         36.816700      NaN
# 178278       AUSTRALIA              NaN               NaN      NaN
# 178279             NaN              NaN               NaN      NaN
# 178280       AUSTRALIA              NaN               NaN      NaN
#
#         ac_damaged  ac_airborne
# 0              NaN         20.0
# 1              NaN          NaN
# 2              NaN         18.0
# 3              NaN         15.0
# 4              NaN          NaN
# 5              NaN          NaN
# 6              NaN          NaN
# 7              NaN          NaN
# 8              NaN          0.0
# 9              NaN          0.0
# 10             NaN          NaN
# 11             NaN          NaN
# 12             NaN          5.0
# 13             NaN          NaN
# 14             NaN          NaN
# 15             NaN          NaN
# 16             NaN          NaN
# 17             NaN          NaN
# 18             NaN          NaN
# 19             NaN          NaN
# 20             NaN          NaN
# 21             NaN          NaN
# 22             NaN          NaN
# 23             NaN          NaN
# 24             NaN          NaN
# 25             NaN          NaN
# 26             NaN          NaN
# 27             NaN          NaN
# 28             NaN          NaN
# 29             NaN          NaN
# ...            ...          ...
# 178251         NaN          NaN
# 178252         NaN          NaN
# 178253         NaN          1.0
# 178254         NaN          NaN
# 178255         NaN          NaN
# 178256         NaN          NaN
# 178257         NaN          3.0
# 178258         NaN          NaN
# 178259         NaN          NaN
# 178260         NaN          NaN
# 178261         NaN          NaN
# 178262         NaN          NaN
# 178263         NaN          NaN
# 178264         NaN          5.0
# 178265         NaN          NaN
# 178266         NaN          NaN
# 178267         NaN          4.0
# 178268         NaN          NaN
# 178269         NaN          NaN
# 178270         NaN          6.0
# 178271         NaN          6.0
# 178272         NaN          NaN
# 178273         NaN          NaN
# 178274         NaN          NaN
# 178275         NaN          5.0
# 178276         NaN         10.0
# 178277         NaN          2.0
# 178278         NaN          NaN
# 178279         NaN          NaN
# 178280         NaN          NaN
#
# [178281 rows x 41 columns]

# %%
wd=Weather['Date'].values.tolist()
new=[]

for x in wd:
   year,month,day=x.split('-')
   if len(month)<2:
       month='0'+month
   if len(day)<2:
       day='0'+day
   new.append(int(year+month+day))

# %%
Weather["Date"] = new

# %%
type(Weather['Date'][1])
# Out:
# numpy.int64

# %%
Weather.head()
# Out:
#      STA      Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp  \
# 0  10001  19420701  1.016          NaN  25.555556  22.222222  23.888889
# 1  10001  19420702      0          NaN  28.888889  21.666667  25.555556
# 2  10001  19420703   2.54          NaN  26.111111  22.222222  24.444444
# 3  10001  19420704   2.54          NaN  26.666667  22.222222  24.444444
# 4  10001  19420705      0          NaN  26.666667  21.666667  24.444444
#
#   Snowfall
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
engine = create_engine('mysql://group07:KnuUyh4WWRqHDxNY@cwru-data-project02.ciuevunbeloh.us-east-2.rds.amazonaws.com:3306/group07')
con = engine.connect()

# %% [markdown]
# mission.to_sql(mission, con,group07,index=False)

# %%
missions.to_sql('mission', con, 'group07' ,index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-5496de86a34c> in <module>()
#       1
# ----> 2 missions.to_sql('missions', con, 'group07' ,index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1146                          if_exists=if_exists, index_label=index_label,
#    1147                          schema=schema, dtype=dtype)
# -> 1148         table.create()
#    1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     561         if self.exists():
#     562             if self.if_exists == 'fail':
# --> 563                 raise ValueError("Table '%s' already exists." % self.name)
#     564             elif self.if_exists == 'replace':
#     565                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'missions' already exists.
